# %%
# %tensorflow_version 1.x
import sys
sys.path.append('/content/drive/My Drive/Colab_Work/PPM/nn/conv')
from minivggnet import MiniVGGNet
sys.path.append('/content/drive/My Drive/Colab_Work/PPM/callbacks')
from trainingmonitor import TrainingMonitor
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from keras.optimizers import SGD
from keras.datasets import cifar10
#import matplotlib.pyplot as plt
import matplotlib
matplotlib.use("Agg")
import numpy as np
import os

# %%
print("[INFO] process ID: {}".format(os.getpid()))

print("[INFO] loading CIFAR-10 data...")

((trainX, trainY), (testX, testY)) = cifar10.load_data()

trainX = trainX.astype("float")/255.0
testX = testX.astype("float")/255.0

trainY = LabelBinarizer().fit_transform(trainY)
testY = LabelBinarizer().fit_transform(testY)

labelNames = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
# Out:
# [INFO] process ID: 1736
# [INFO] loading CIFAR-10 data...

# %%
print("[INFO] compiling model...")
opt = SGD(lr=0.01, momentum=0.9, nesterov=True)
model = MiniVGGNet.build(width=32, height=32, depth=3, classes=10)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
# Out:
# [INFO] compiling model...

# %%
# %cd /content/drive/My\ Drive/Colab_Work/monitor_output
print("[INFO] process ID: {}".format(os.getpid()))
figPath = os.path.sep.join(['figs', "{}.png".format(os.getpid())])
#jsonPath = os.path.sep.join(['json_files', "{}.json".format(os.getpid())])

callbacks = [TrainingMonitor(figPath, jsonPath=jsonPath)]
# Out:
# /content/drive/My Drive/Colab_Work/monitor_output
# [INFO] process ID: 1736

# %%
print("[INFO] training network...")
H = model.fit(trainX,  trainY, validation_data=(testX, testY), batch_size=64, epochs=100, callbacks=callbacks, verbose=1)
# Out:
# [INFO] training network...
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 16s 326us/step - loss: 1.6283 - acc: 0.4573 - val_loss: 1.5501 - val_acc: 0.4717
# Epoch 2/100
# 50000/50000 [==============================] - 15s 300us/step - loss: 1.1753 - acc: 0.5956 - val_loss: 1.1698 - val_acc: 0.6069
# Epoch 3/100
# 50000/50000 [==============================] - 15s 307us/step - loss: 0.9813 - acc: 0.6586 - val_loss: 0.9824 - val_acc: 0.6663
# Epoch 4/100
# 50000/50000 [==============================] - 15s 308us/step - loss: 0.8725 - acc: 0.6963 - val_loss: 0.8088 - val_acc: 0.7207
# Epoch 5/100
# 50000/50000 [==============================] - 15s 305us/step - loss: 0.7905 - acc: 0.7240 - val_loss: 0.7301 - val_acc: 0.7529
# Epoch 6/100
# 50000/50000 [==============================] - 15s 307us/step - loss: 0.7285 - acc: 0.7460 - val_loss: 0.9919 - val_acc: 0.6709
# Epoch 7/100
# 50000/50000 [==============================] - 16s 314us/step - loss: 0.6792 - acc: 0.7616 - val_loss: 0.7020 - val_acc: 0.7622
# Epoch 8/100
# 50000/50000 [==============================] - 15s 303us/step - loss: 0.6338 - acc: 0.7792 - val_loss: 0.6595 - val_acc: 0.7735
# Epoch 9/100
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.5931 - acc: 0.7924 - val_loss: 0.6795 - val_acc: 0.7677
# Epoch 10/100
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.5537 - acc: 0.8053 - val_loss: 0.5704 - val_acc: 0.8020
# Epoch 11/100
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.5190 - acc: 0.8172 - val_loss: 0.5842 - val_acc: 0.7981
# Epoch 12/100
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.4908 - acc: 0.8291 - val_loss: 0.5973 - val_acc: 0.7930
# Epoch 13/100
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.4615 - acc: 0.8377 - val_loss: 0.5698 - val_acc: 0.8040
# Epoch 14/100
# 50000/50000 [==============================] - 15s 293us/step - loss: 0.4378 - acc: 0.8456 - val_loss: 0.5595 - val_acc: 0.8107
# Epoch 15/100
# 50000/50000 [==============================] - 15s 295us/step - loss: 0.4191 - acc: 0.8514 - val_loss: 0.5756 - val_acc: 0.8114
# Epoch 16/100
# 50000/50000 [==============================] - 15s 295us/step - loss: 0.4033 - acc: 0.8588 - val_loss: 0.6010 - val_acc: 0.8056
# Epoch 17/100
# 50000/50000 [==============================] - 15s 298us/step - loss: 0.3741 - acc: 0.8680 - val_loss: 0.5761 - val_acc: 0.8126
# Epoch 18/100
# 50000/50000 [==============================] - 15s 297us/step - loss: 0.3534 - acc: 0.8749 - val_loss: 0.5830 - val_acc: 0.8163
# Epoch 19/100
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.3380 - acc: 0.8797 - val_loss: 0.5721 - val_acc: 0.8087
# Epoch 20/100
# 50000/50000 [==============================] - 15s 296us/step - loss: 0.3259 - acc: 0.8845 - val_loss: 0.5652 - val_acc: 0.8141
# Epoch 21/100
# 50000/50000 [==============================] - 15s 297us/step - loss: 0.3023 - acc: 0.8925 - val_loss: 0.6095 - val_acc: 0.8110
# Epoch 22/100
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.2966 - acc: 0.8940 - val_loss: 0.5925 - val_acc: 0.8138
# Epoch 23/100
# 50000/50000 [==============================] - 15s 295us/step - loss: 0.2872 - acc: 0.8979 - val_loss: 0.6198 - val_acc: 0.8149
# Epoch 24/100
# 50000/50000 [==============================] - 15s 298us/step - loss: 0.2784 - acc: 0.9007 - val_loss: 0.5859 - val_acc: 0.8188
# Epoch 25/100
# 50000/50000 [==============================] - 15s 298us/step - loss: 0.2551 - acc: 0.9098 - val_loss: 0.5809 - val_acc: 0.8206
# Epoch 26/100
# 50000/50000 [==============================] - 15s 295us/step - loss: 0.2535 - acc: 0.9099 - val_loss: 0.5597 - val_acc: 0.8234
# Epoch 27/100
# 50000/50000 [==============================] - 15s 298us/step - loss: 0.2447 - acc: 0.9138 - val_loss: 0.5685 - val_acc: 0.8242
# Epoch 28/100
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.2381 - acc: 0.9151 - val_loss: 0.5939 - val_acc: 0.8210
# Epoch 29/100
# 50000/50000 [==============================] - 15s 296us/step - loss: 0.2295 - acc: 0.9190 - val_loss: 0.5653 - val_acc: 0.8269
# Epoch 30/100
# 50000/50000 [==============================] - 15s 293us/step - loss: 0.2230 - acc: 0.9202 - val_loss: 0.5750 - val_acc: 0.8221
# Epoch 31/100
# 50000/50000 [==============================] - 15s 294us/step - loss: 0.2136 - acc: 0.9235 - val_loss: 0.6008 - val_acc: 0.8211
# Epoch 32/100
# 50000/50000 [==============================] - 15s 296us/step - loss: 0.2033 - acc: 0.9265 - val_loss: 0.5931 - val_acc: 0.8235
# Epoch 33/100
# 50000/50000 [==============================] - 15s 297us/step - loss: 0.1990 - acc: 0.9282 - val_loss: 0.5864 - val_acc: 0.8242
# Epoch 34/100
# 50000/50000 [==============================] - 15s 293us/step - loss: 0.1982 - acc: 0.9291 - val_loss: 0.5885 - val_acc: 0.8254
# Epoch 35/100
# 50000/50000 [==============================] - 15s 294us/step - loss: 0.1911 - acc: 0.9307 - val_loss: 0.6184 - val_acc: 0.8297
# Epoch 36/100
# 50000/50000 [==============================] - 15s 295us/step - loss: 0.1831 - acc: 0.9340 - val_loss: 0.6019 - val_acc: 0.8248
# Epoch 37/100
# 50000/50000 [==============================] - 15s 295us/step - loss: 0.1827 - acc: 0.9356 - val_loss: 0.5931 - val_acc: 0.8312
# Epoch 38/100
# 28864/50000 [================>.............] - ETA: 5s - loss: 0.1722 - acc: 0.9395
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-f21a211adeac> in <module>()
#       1 print("[INFO] training network...")
# ----> 2 H = model.fit(trainX,  trainY, validation_data=(testX, testY), batch_size=64, epochs=100, callbacks=callbacks, verbose=1)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
