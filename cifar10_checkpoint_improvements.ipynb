# %%
# %tensorflow_version 1.x
import sys
sys.path.append('/content/drive/My Drive/Colab_Work/PPM/nn/conv')
from minivggnet import MiniVGGNet
sys.path.append('/content/drive/My Drive/Colab_Work/PPM/callbacks')
from trainingmonitor import TrainingMonitor
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LearningRateScheduler
from keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np
import os
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
print("[INFO] loading CIFAR-10 data...")

((trainX, trainY), (testX, testY)) = cifar10.load_data()

trainX = trainX.astype("float")/255.0
testX = testX.astype("float")/255.0

trainY = LabelBinarizer().fit_transform(trainY)
testY = LabelBinarizer().fit_transform(testY)

labelNames = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
# Out:
# [INFO] loading CIFAR-10 data...

# %%
print("[INFO] compiling model...")
opt = SGD(lr=0.01, momentum=0.9, nesterov=True)
model = MiniVGGNet.build(width=32, height=32, depth=3, classes=10)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
# Out:
# [INFO] compiling model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# %cd /content/drive/My\ Drive/Colab_Work
fname = os.path.sep.join(['minivggnet_checkpoints', "weights-{epoch:03d}-{val_loss:.4f}.hdf5"])
checkpoint = ModelCheckpoint(fname, monitor="val_loss", mode="min", save_best_only=True, verbose=1)
callbacks = [checkpoint]
# Out:
# /content/drive/My Drive/Colab_Work

# %%
print("[INFO] training network...")
H = model.fit(trainX,  trainY, validation_data=(testX, testY), batch_size=64, epochs=40, callbacks=callbacks, verbose=1)
# Out:
# [INFO] training network...
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 14s 270us/step - loss: 1.6579 - acc: 0.4479 - val_loss: 1.1966 - val_acc: 0.5863
#
# Epoch 00001: val_loss improved from inf to 1.19660, saving model to minivggnet_checkpoints/weights-001-1.1966.hdf5
# Epoch 2/40
# 50000/50000 [==============================] - 11s 229us/step - loss: 1.1870 - acc: 0.5914 - val_loss: 1.1571 - val_acc: 0.6116
#
# Epoch 00002: val_loss improved from 1.19660 to 1.15712, saving model to minivggnet_checkpoints/weights-002-1.1571.hdf5
# Epoch 3/40
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.9944 - acc: 0.6561 - val_loss: 0.8625 - val_acc: 0.7069
#
# Epoch 00003: val_loss improved from 1.15712 to 0.86250, saving model to minivggnet_checkpoints/weights-003-0.8625.hdf5
# Epoch 4/40
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.8754 - acc: 0.6956 - val_loss: 0.8384 - val_acc: 0.7182
#
# Epoch 00004: val_loss improved from 0.86250 to 0.83839, saving model to minivggnet_checkpoints/weights-004-0.8384.hdf5
# Epoch 5/40
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.8010 - acc: 0.7201 - val_loss: 0.7463 - val_acc: 0.7433
#
# Epoch 00005: val_loss improved from 0.83839 to 0.74628, saving model to minivggnet_checkpoints/weights-005-0.7463.hdf5
# Epoch 6/40
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.7403 - acc: 0.7406 - val_loss: 0.7495 - val_acc: 0.7384
#
# Epoch 00006: val_loss did not improve from 0.74628
# Epoch 7/40
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.6859 - acc: 0.7592 - val_loss: 0.6627 - val_acc: 0.7744
#
# Epoch 00007: val_loss improved from 0.74628 to 0.66270, saving model to minivggnet_checkpoints/weights-007-0.6627.hdf5
# Epoch 8/40
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.6358 - acc: 0.7762 - val_loss: 0.6337 - val_acc: 0.7792
#
# Epoch 00008: val_loss improved from 0.66270 to 0.63368, saving model to minivggnet_checkpoints/weights-008-0.6337.hdf5
# Epoch 9/40
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.6020 - acc: 0.7897 - val_loss: 0.6311 - val_acc: 0.7814
#
# Epoch 00009: val_loss improved from 0.63368 to 0.63111, saving model to minivggnet_checkpoints/weights-009-0.6311.hdf5
# Epoch 10/40
# 50000/50000 [==============================] - 12s 230us/step - loss: 0.5686 - acc: 0.8003 - val_loss: 0.6146 - val_acc: 0.7886
#
# Epoch 00010: val_loss improved from 0.63111 to 0.61465, saving model to minivggnet_checkpoints/weights-010-0.6146.hdf5
# Epoch 11/40
# 50000/50000 [==============================] - 12s 231us/step - loss: 0.5349 - acc: 0.8115 - val_loss: 0.6502 - val_acc: 0.7844
#
# Epoch 00011: val_loss did not improve from 0.61465
# Epoch 12/40
# 50000/50000 [==============================] - 11s 228us/step - loss: 0.5004 - acc: 0.8231 - val_loss: 0.6586 - val_acc: 0.7791
#
# Epoch 00012: val_loss did not improve from 0.61465
# Epoch 13/40
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.4851 - acc: 0.8298 - val_loss: 0.6182 - val_acc: 0.7982
#
# Epoch 00013: val_loss did not improve from 0.61465
# Epoch 14/40
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.4562 - acc: 0.8382 - val_loss: 0.5890 - val_acc: 0.8080
#
# Epoch 00014: val_loss improved from 0.61465 to 0.58899, saving model to minivggnet_checkpoints/weights-014-0.5890.hdf5
# Epoch 15/40
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.4341 - acc: 0.8460 - val_loss: 0.5762 - val_acc: 0.8108
#
# Epoch 00015: val_loss improved from 0.58899 to 0.57618, saving model to minivggnet_checkpoints/weights-015-0.5762.hdf5
# Epoch 16/40
# 50000/50000 [==============================] - 11s 228us/step - loss: 0.4078 - acc: 0.8554 - val_loss: 0.5853 - val_acc: 0.8105
#
# Epoch 00016: val_loss did not improve from 0.57618
# Epoch 17/40
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.3908 - acc: 0.8605 - val_loss: 0.5610 - val_acc: 0.8151
#
# Epoch 00017: val_loss improved from 0.57618 to 0.56097, saving model to minivggnet_checkpoints/weights-017-0.5610.hdf5
# Epoch 18/40
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.3708 - acc: 0.8672 - val_loss: 0.5808 - val_acc: 0.8072
#
# Epoch 00018: val_loss did not improve from 0.56097
# Epoch 19/40
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.3553 - acc: 0.8751 - val_loss: 0.5948 - val_acc: 0.8053
#
# Epoch 00019: val_loss did not improve from 0.56097
# Epoch 20/40
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.3417 - acc: 0.8779 - val_loss: 0.6400 - val_acc: 0.7929
#
# Epoch 00020: val_loss did not improve from 0.56097
# Epoch 21/40
# 50000/50000 [==============================] - 11s 229us/step - loss: 0.3289 - acc: 0.8813 - val_loss: 0.5810 - val_acc: 0.8180
#
# Epoch 00021: val_loss did not improve from 0.56097
# Epoch 22/40
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.3093 - acc: 0.8891 - val_loss: 0.5755 - val_acc: 0.8160
#
# Epoch 00022: val_loss did not improve from 0.56097
# Epoch 23/40
# 50000/50000 [==============================] - 12s 230us/step - loss: 0.2995 - acc: 0.8918 - val_loss: 0.5839 - val_acc: 0.8211
#
# Epoch 00023: val_loss did not improve from 0.56097
# Epoch 24/40
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.2911 - acc: 0.8949 - val_loss: 0.5900 - val_acc: 0.8192
#
# Epoch 00024: val_loss did not improve from 0.56097
# Epoch 25/40
# 50000/50000 [==============================] - 11s 228us/step - loss: 0.2760 - acc: 0.9012 - val_loss: 0.5815 - val_acc: 0.8199
#
# Epoch 00025: val_loss did not improve from 0.56097
# Epoch 26/40
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.2739 - acc: 0.9031 - val_loss: 0.6245 - val_acc: 0.8088
#
# Epoch 00026: val_loss did not improve from 0.56097
# Epoch 27/40
# 50000/50000 [==============================] - 11s 226us/step - loss: 0.2549 - acc: 0.9093 - val_loss: 0.5881 - val_acc: 0.8263
#
# Epoch 00027: val_loss did not improve from 0.56097
# Epoch 28/40
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.2482 - acc: 0.9122 - val_loss: 0.5897 - val_acc: 0.8267
#
# Epoch 00028: val_loss did not improve from 0.56097
# Epoch 29/40
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.2483 - acc: 0.9116 - val_loss: 0.7396 - val_acc: 0.7839
#
# Epoch 00029: val_loss did not improve from 0.56097
# Epoch 30/40
# 50000/50000 [==============================] - 11s 230us/step - loss: 0.2467 - acc: 0.9109 - val_loss: 0.6130 - val_acc: 0.8204
#
# Epoch 00030: val_loss did not improve from 0.56097
# Epoch 31/40
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.2291 - acc: 0.9189 - val_loss: 0.5995 - val_acc: 0.8265
#
# Epoch 00031: val_loss did not improve from 0.56097
# Epoch 32/40
# 50000/50000 [==============================] - 11s 227us/step - loss: 0.2158 - acc: 0.9229 - val_loss: 0.6442 - val_acc: 0.8184
#
# Epoch 00032: val_loss did not improve from 0.56097
# Epoch 33/40
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.2092 - acc: 0.9243 - val_loss: 0.6478 - val_acc: 0.8168
#
# Epoch 00033: val_loss did not improve from 0.56097
# Epoch 34/40
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.2086 - acc: 0.9258 - val_loss: 0.5843 - val_acc: 0.8264
#
# Epoch 00034: val_loss did not improve from 0.56097
# Epoch 35/40
# 50000/50000 [==============================] - 12s 231us/step - loss: 0.1968 - acc: 0.9297 - val_loss: 0.6181 - val_acc: 0.8286
#
# Epoch 00035: val_loss did not improve from 0.56097
# Epoch 36/40
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.1965 - acc: 0.9297 - val_loss: 0.6307 - val_acc: 0.8142
#
# Epoch 00036: val_loss did not improve from 0.56097
# Epoch 37/40
# 50000/50000 [==============================] - 12s 232us/step - loss: 0.1976 - acc: 0.9307 - val_loss: 0.5970 - val_acc: 0.8237
#
# Epoch 00037: val_loss did not improve from 0.56097
# Epoch 38/40
# 50000/50000 [==============================] - 11s 224us/step - loss: 0.1841 - acc: 0.9351 - val_loss: 0.5936 - val_acc: 0.8278
#
# Epoch 00038: val_loss did not improve from 0.56097
# Epoch 39/40
# 50000/50000 [==============================] - 11s 223us/step - loss: 0.1837 - acc: 0.9346 - val_loss: 0.6413 - val_acc: 0.8226
#
# Epoch 00039: val_loss did not improve from 0.56097
# Epoch 40/40
# 50000/50000 [==============================] - 11s 225us/step - loss: 0.1778 - acc: 0.9350 - val_loss: 0.6224 - val_acc: 0.8272
#
# Epoch 00040: val_loss did not improve from 0.56097
